# %%
import os 
import requests
from bs4 import BeautifulSoup
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Comment out API keys to avoid running cells by accident

# api read key created at https://develop.purpleair.com/keys
api_read_key = "1A4A4B7E-BF7D-11EE-8616-42010A80000B"

# api write key created at https://develop.purpleair.com/keys
api_write_key = "FFAF2E2E-BF85-11EE-8616-42010A80000B"

# %%
# open variables json and assign to p_air_vars variable
with open('purple-air-variables.json') as f:
    p_air_vars = json.load(f)

# pull in the list of test sensors as sensor_test
sensor_test = p_air_vars['sensor_test']
sensor_test
# Out:
# [53, 77, 81, 443, 820]

# %%
# create function to pull all data from a sensor
def pull_sensor_data(sensor_id, p_air_READ_API_key):
    url = f"https://api.purpleair.com/v1/sensors/{sensor_id}"
    headers = {
        "X-API-Key": p_air_READ_API_key
        }
    
    sensor_response = requests.get(url, headers=headers)
    sensor_response_json = sensor_response.json()
    sensor_data = sensor_response_json.get('sensor')
    return sensor_data

# %%
list_of_test_sensors = []

for sensor in sensor_test:
    sensor_data = pull_sensor_data(sensor, api_read_key)
    list_of_test_sensors.append(sensor_data)

# %%
sample_sensor_df = pd.DataFrame(list_of_test_sensors)
sample_sensor_df
# Out:
#    sensor_index  last_modified  date_created   last_seen  private  is_owner  \
# 0            53     1520025982    1454548891  1707077195        0         0
# 1            77     1575074907    1456896339  1707077203        0         0
# 2            81     1465680292    1465657200  1707077203        0         0
# 3           443     1559966508    1478491864  1707077121        0         0
# 4           820     1575003401    1483643179  1707077255        0         0
#
#                                 name  icon  location_type    model  ...  \
# 0                          Lakeshore     0              0  UNKNOWN  ...
# 1                          Sunnyside     0              0     PA-I  ...
# 2                   Sherwood Hills 2     0              0  UNKNOWN  ...
# 3  Weber-Morgan Health Department P1     0              0    PA-II  ...
# 4                   Granite Basement     0              1    PA-II  ...
#
#   5.0_um_count_b  10.0_um_count_b pm1.0_cf_1_b  pm1.0_atm_b  pm2.5_atm_b  \
# 0            NaN              NaN          NaN          NaN          NaN
# 1            NaN              NaN          NaN          NaN          NaN
# 2            NaN              NaN          NaN          NaN          NaN
# 3            0.0              0.0         6.21         6.21         6.44
# 4            0.0              0.0         0.00         0.00         0.00
#
#    pm2.5_cf_1_b  pm10.0_atm_b  pm10.0_cf_1_b  \
# 0           NaN           NaN            NaN
# 1           NaN           NaN            NaN
# 2           NaN           NaN            NaN
# 3          6.44          6.44           6.44
# 4          0.00          0.00           0.00
#
#                                              stats_b  altitude
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  {'pm2.5': 6.4, 'pm2.5_10minute': 7.0, 'pm2.5_3...       NaN
# 4  {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_3...    5131.0
#
# [5 rows x 103 columns]

# %%
sample_sensor_df['last_modified'] = pd.to_datetime(sample_sensor_df['last_modified'], unit='s')
sample_sensor_df['date_created'] = pd.to_datetime(sample_sensor_df['date_created'], unit='s')
sample_sensor_df['last_seen'] = pd.to_datetime(sample_sensor_df['last_seen'], unit='s')

# %%
# commented out below, .csv exists in repo after first run, no longer needed

#sample_sensor_df.to_csv("sample_sensors.csv")

# %% [markdown]
# # Use all sensor data below

# %%
# pull in the list of ALL SLC sensors as slc_sensor_list
slc_sensor_list = p_air_vars['slc_sensor_list']

# %%
## EXPENSIVE cell. Pulls all 100+ columns for all 600+ sensors in SLC, outdoor and indoor
## The results are saved to slc_sensor_data_20240130.csv

# pull all SLC sensors into a list
# Cost of cell: 95480
# Time to run: 4 minutes

#list_of_slc_sensors = []

#for sensor in slc_sensor_list:
#    sensor_data = pull_sensor_data(sensor, api_read_key)
#    list_of_slc_sensors.append(sensor_data)

# %%
#slc_sensors_df = pd.DataFrame(list_of_slc_sensors)
#slc_sensors_df.to_csv('slc_sensor_data_20240130.csv')

# %%
# read in SLC sensor data from 1/30/24 snapshot
slc_sensor_eda = pd.read_csv('slc_sensor_data_20240130.csv')

# %%
slc_sensor_eda.describe()
# Out:
#        Unnamed: 0  sensor_index  last_modified  date_created     last_seen  \
# count  616.000000     616.00000   6.160000e+02  6.160000e+02  6.160000e+02
# mean   307.500000   72891.12013   1.619314e+09  1.586838e+09  1.706636e+09
# std    177.968162   60211.10269   4.582785e+07  5.573370e+07  4.218151e+04
# min      0.000000      53.00000   1.465680e+09  1.454549e+09  1.706164e+09
# 25%    153.750000   16260.00000   1.575398e+09  1.537884e+09  1.706641e+09
# 50%    307.500000   49683.00000   1.626983e+09  1.583598e+09  1.706641e+09
# 75%    461.250000  122074.50000   1.647643e+09  1.629497e+09  1.706641e+09
# max    615.000000  208783.00000   1.706563e+09  1.703862e+09  1.706641e+09
#
#        private  is_owner   icon  location_type  led_brightness  ...  \
# count    616.0     616.0  616.0     616.000000      616.000000  ...
# mean       0.0       0.0    0.0       0.258117       35.357143  ...
# std        0.0       0.0    0.0       0.437954        7.914321  ...
# min        0.0       0.0    0.0       0.000000        5.000000  ...
# 25%        0.0       0.0    0.0       0.000000       35.000000  ...
# 50%        0.0       0.0    0.0       0.000000       35.000000  ...
# 75%        0.0       0.0    0.0       1.000000       35.000000  ...
# max        0.0       0.0    0.0       1.000000      100.000000  ...
#
#        pm2.5_cf_1_b  pm10.0_atm_b  pm10.0_cf_1_b     altitude  ozone1  \
# count    487.000000    487.000000     487.000000   605.000000     1.0
# mean     197.918234    140.514045     200.471335  4932.745455   145.0
# std      934.066822    621.099381     933.626790   796.948542     NaN
# min        0.000000      0.000000       0.000000  4219.000000   145.0
# 25%        6.035000      7.200000       7.200000  4418.000000   145.0
# 50%       21.020000     23.050000      23.050000  4652.000000   145.0
# 75%       32.060000     35.335000      35.335000  5075.000000   145.0
# max     6091.400000   4060.250000    6091.400000  8804.000000   145.0
#
#        humidity_b  temperature_b  pressure_b         voc       voc_b
# count   56.000000      56.000000   56.000000   56.000000   56.000000
# mean    25.482143      72.482143  856.775893  117.473214  117.477500
# std     10.421989      14.322254   20.808866  113.629944  113.626979
# min     11.000000      43.000000  798.910000   50.000000   50.000000
# 25%     18.000000      61.000000  849.665000   56.925000   56.922500
# 50%     24.500000      70.000000  863.955000   69.250000   69.250000
# 75%     29.000000      86.000000  869.992500  114.550000  114.540000
# max     65.000000      93.000000  880.020000  532.400000  532.370000
#
# [8 rows x 99 columns]

# %%
slc_sensor_eda.nunique()
# Out:
# Unnamed: 0       616
# sensor_index     616
# last_modified    616
# date_created     616
# last_seen        278
#                 ...
# humidity_b        27
# temperature_b     33
# pressure_b        55
# voc               53
# voc_b             54
# Length: 110, dtype: int64

# %%
# look at value counts for each column
# skip the first two columns since we know they'll all be unique
for column in slc_sensor_eda.columns[2:]:
    value_counts = slc_sensor_eda[column].value_counts()
    print(f'Column: {column}\n{value_counts}\n')
# Out:
# Column: last_modified
# 1520025982    1
# 1630852908    1
# 1629328369    1
# 1631251784    1
# 1631251712    1
#              ..
# 1616983651    1
# 1548026904    1
# 1575088844    1
# 1575004554    1
# 1706498344    1
# Name: last_modified, Length: 616, dtype: int64
#
# Column: date_created
# 1454548891    1
# 1625008888    1
# 1624396549    1
# 1624482883    1
# 1624482885    1
#              ..
# 1547074682    1
# 1547228302    1
# 1547232395    1
# 1547745418    1
# 1703862440    1
# Name: date_created, Length: 616, dtype: int64
#
# Column: last_seen
# 1706641222    9
# 1706641173    7
# 1706641183    7
# 1706641257    7
# 1706641272    7
#              ..
# 1706641121    1
# 1706641041    1
# 1706641178    1
# 1706641202    1
# 1706641396    1
# Name: last_seen, Length: 278, dtype: int64
#
# Column: private
# 0    616
# Name: private, dtype: int64
#
# Column: is_owner
# 0    616
# Name: is_owner, dtype: int64
#
# Column: name
# Home                  3
# Wasatch Hollow        2
# Riverton              2
# Buckboard             2
# Payson Utah           2
#                      ..
# Bonneville Academy    1
# OV_DurfeeCreek        1
# Oaks                  1
# Kaysville             1
# JCs house             1
# Name: name, Length: 602, dtype: int64
#
# Column: icon
# 0    616
# Name: icon, dtype: int64
#
# Column: location_type
# 0    457
# 1    159
# Name: location_type, dtype: int64
#
# Column: model
# PA-II         368
# PA-I          114
# PA-II-SD       74
# PA-II-FLEX     45
# PA-I-LED       13
# UNKNOWN         2
# Name: model, dtype: int64
#
# Column: hardware
# 2.0+BME280+PMSX003-B+PMSX003-A                                   324
# 2.0+BME280+PMSX003-A                                             111
# 2.0+OPENLOG+NO-DISK+DS3231+BME280+PMSX003-B+PMSX003-A             27
# 2.0+1M+BME280+PMSX003-B+PMSX003-A                                 25
# 2.0+PMSX003-B+PMSX003-A                                           18
# 2.0+OPENLOG+15476 MB+DS3231+BME280+PMSX003-B+PMSX003-A            14
# 3.0+BME68X+KX122+PMSX003-A                                        12
# 3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX003-A+PMSX003-B        9
# 3.0+RV3028+BME68X+KX122+PMSX003-A+PMSX003-B                        9
# 3.0+RV3028+BME68X+PMSX003-A+PMSX003-B                              8
# 3.0+DS3231+BME280+BME68X+PMSX003-A+PMSX003-B                       5
# 2.0+OPENLOG+31037 MB+DS3231+BME280+PMSX003-B+PMSX003-A             5
# 2.0+OPENLOG+15931 MB+DS3231+BME280+PMSX003-B+PMSX003-A             5
# 3.0+OPENLOG+NO-DISK+RV3028+BME68X+PMSX003-A+PMSX003-B              5
# 2.0+OPENLOG+15980 MB+DS3231+BME280+PMSX003-B+PMSX003-A             4
# 2.0+OPENLOG+15802 MB+DS3231+BME280+PMSX003-B+PMSX003-A             3
# 2.0+OPENLOG+15833 MB+DS3231+BME280+PMSX003-B+PMSX003-A             3
# 2.0+OPENLOG+15485 MB+DS3231+BME280+PMSX003-B+PMSX003-A             3
# 2.0+OPENLOG+15560 MB+DS3231+BME280+PMSX003-B+PMSX003-A             2
# 3.0+PMSX003-A+PMSX003-B                                            2
# 2.0+DS3231+BME280+PMSX003-B+PMSX003-A                              2
# 2.0+OPENLOG+NO-DISK+DS3231+PMSX003-B+PMSX003-A                     2
# 1.0+1M+PMSX003-O                                                   2
# 3.0+OPENLOG+31954 MB+RV3028+BME68X+PMSX003-A+PMSX003-B             1
# 3.0+OPENLOG+31037 MB+RV3028+BME68X+PMSX003-A+PMSX003-B             1
# 2.0+OPENLOG+31954 MB+DS3231+BME280+PMSX003-B+PMSX003-A             1
# 3.0+BME280+BME68X+PMSX003-A                                        1
# 3.0+OPENLOG+31037 MB+RV3028+BME280+BME68X+PMSX003-A+PMSX003-B      1
# 3.0+OPENLOG+NO-DISK+DS3231+BME280+BME68X+PMSX003-A+PMSX003-B       1
# 2.0+BME280+BME68X+PMSX003-A                                        1
# 2.0+OPENLOG+15476 MB+PMSX003-B+PMSX003-A                           1
# 2.0+PMSX003-A                                                      1
# 3.0+DS3231+BME280+BME68X+PMSX003-A-R+PMSX003-B                     1
# 2.0+1M+PMSX003-A                                                   1
# 3.0+DS3231+PMSX003-A+PMSX003-B                                     1
# 2.0+OPENLOG+31914 MB+DS3231+BME280+PMSX003-B+PMSX003-A             1
# 2.0+OPENLOG+15836 MB+DS3231+BME280+PMSX003-B+PMSX003-A             1
# 2.0+1M+PMSX003-B+PMSX003-A                                         1
# 3.0+OPENLOG+NO-DISK+BME68X+KX122+PMSX003-A+PMSX003-B               1
# Name: hardware, dtype: int64
#
# Column: led_brightness
# 35     582
# 5        8
# 50       8
# 100      6
# 25       5
# 15       4
# 60       2
# 65       1
# Name: led_brightness, dtype: int64
#
# Column: firmware_version
# 7.02     529
# 7.04      58
# 6.06b     29
# Name: firmware_version, dtype: int64
#
# Column: rssi
# -72    25
# -70    23
# -67    23
# -62    21
# -61    21
#        ..
# -92     1
# -29     1
# -89     1
# -35     1
# -96     1
# Name: rssi, Length: 69, dtype: int64
#
# Column: uptime
# 62098    14
# 62099    11
# 62115     7
# 62117     6
# 62097     6
#          ..
# 9185      1
# 9895      1
# 28983     1
# 62683     1
# 915       1
# Name: uptime, Length: 540, dtype: int64
#
# Column: pa_latency
# 238.0     12
# 234.0      9
# 281.0      8
# 231.0      8
# 252.0      8
#           ..
# 523.0      1
# 2281.0     1
# 703.0      1
# 465.0      1
# 485.0      1
# Name: pa_latency, Length: 309, dtype: int64
#
# Column: memory
# 15728    24
# 15936    23
# 15696    22
# 16104    20
# 15704    20
#          ..
# 15232     1
# 15408     1
# 15520     1
# 16032     1
# 5752      1
# Name: memory, Length: 171, dtype: int64
#
# Column: position_rating
# 5    528
# 0     62
# 4      9
# 3      9
# 1      5
# 2      3
# Name: position_rating, dtype: int64
#
# Column: latitude
# 40.713238    2
# 40.681170    2
# 40.663070    2
# 40.246742    1
# 40.211560    1
#             ..
# 41.384926    1
# 40.778870    1
# 41.024460    1
# 40.723434    1
# 40.761765    1
# Name: latitude, Length: 613, dtype: int64
#
# Column: longitude
# -111.886010    2
# -111.847490    2
# -111.791480    2
# -111.826485    2
# -111.479340    2
#               ..
# -111.924194    1
# -112.323530    1
# -111.900770    1
# -111.757520    1
# -111.594680    1
# Name: longitude, Length: 609, dtype: int64
#
# Column: channel_state
# 3    487
# 1    129
# Name: channel_state, dtype: int64
#
# Column: channel_flags
# 0    547
# 2     35
# 1     34
# Name: channel_flags, dtype: int64
#
# Column: channel_flags_manual
# 0    591
# 1     17
# 2      8
# Name: channel_flags_manual, dtype: int64
#
# Column: channel_flags_auto
# 0    558
# 2     34
# 1     24
# Name: channel_flags_auto, dtype: int64
#
# Column: confidence
# 100    370
# 30     129
# 0       46
# 80      10
# 97       4
# 98       3
# 82       3
# 1        3
# 94       3
# 2        2
# 84       2
# 96       2
# 83       2
# 92       2
# 85       2
# 18       2
# 9        2
# 60       2
# 77       2
# 99       2
# 8        1
# 48       1
# 66       1
# 72       1
# 63       1
# 37       1
# 89       1
# 95       1
# 54       1
# 40       1
# 3        1
# 79       1
# 33       1
# 7        1
# 6        1
# 91       1
# 57       1
# 36       1
# 87       1
# 61       1
# 69       1
# 73       1
# 52       1
# Name: confidence, dtype: int64
#
# Column: analog_input
# 0.02    163
# 0.00    120
# 0.01    120
# 0.03     76
# 0.04     54
# 0.05     44
# 0.06     15
# 0.07      4
# 0.08      4
# 0.09      2
# 0.60      2
# 0.97      2
# 0.32      1
# 1.37      1
# 1.67      1
# 0.92      1
# 0.50      1
# 0.87      1
# 1.41      1
# 0.59      1
# 4.87      1
# 0.46      1
# Name: analog_input, dtype: int64
#
# Column: pm1.0
# 0.0     108
# 0.2      15
# 0.1       9
# 2.9       7
# 0.8       7
#        ...
# 22.5      1
# 27.5      1
# 24.5      1
# 25.0      1
# 13.3      1
# Name: pm1.0, Length: 233, dtype: int64
#
# Column: pm1.0_a
# 0.0     104
# 0.2      11
# 0.1       9
# 14.2      8
# 0.3       8
#        ...
# 11.7      1
# 27.5      1
# 7.8       1
# 9.6       1
# 2.8       1
# Name: pm1.0_a, Length: 239, dtype: int64
#
# Column: pm2.5
# 0.0     70
# 0.1     11
# 0.2     11
# 0.4      9
# 1.0      8
#         ..
# 4.6      1
# 33.6     1
# 35.3     1
# 18.8     1
# 14.5     1
# Name: pm2.5, Length: 297, dtype: int64
#
# Column: pm2.5_a
# 0.0     70
# 0.2     11
# 0.4      8
# 0.1      8
# 1.0      7
#         ..
# 22.9     1
# 31.1     1
# 35.2     1
# 34.4     1
# 14.0     1
# Name: pm2.5_a, Length: 298, dtype: int64
#
# Column: pm2.5_alt
# 0.0     20
# 0.4     16
# 0.6     13
# 0.3     13
# 0.5     12
#         ..
# 27.6     1
# 3.9      1
# 13.1     1
# 18.3     1
# 8.7      1
# Name: pm2.5_alt, Length: 231, dtype: int64
#
# Column: pm2.5_alt_a
# 0.0     21
# 0.4     16
# 0.9     14
# 0.3     13
# 0.5     12
#         ..
# 17.5     1
# 26.8     1
# 10.4     1
# 8.4      1
# 8.5      1
# Name: pm2.5_alt_a, Length: 232, dtype: int64
#
# Column: pm10.0
# 0.0     55
# 0.4     13
# 0.2     12
# 0.1     11
# 0.3      8
#         ..
# 45.8     1
# 25.5     1
# 8.6      1
# 30.1     1
# 16.9     1
# Name: pm10.0, Length: 319, dtype: int64
#
# Column: pm10.0_a
# 0.0     54
# 0.4     11
# 0.1     11
# 0.2      9
# 0.3      9
#         ..
# 40.8     1
# 44.1     1
# 47.4     1
# 11.6     1
# 21.7     1
# Name: pm10.0_a, Length: 336, dtype: int64
#
# Column: scattering_coefficient
# 1.7     6
# 2.0     6
# 1.3     6
# 1.6     5
# 0.9     5
#        ..
# 11.1    1
# 43.6    1
# 4.5     1
# 38.5    1
# 28.4    1
# Name: scattering_coefficient, Length: 375, dtype: int64
#
# Column: scattering_coefficient_a
# 1.6     6
# 2.8     6
# 1.3     5
# 3.2     5
# 2.0     5
#        ..
# 29.0    1
# 56.7    1
# 59.4    1
# 38.8    1
# 29.4    1
# Name: scattering_coefficient_a, Length: 383, dtype: int64
#
# Column: deciviews
# 17.0    8
# 2.0     7
# 15.9    7
# 1.7     6
# 18.3    6
#        ..
# 15.6    1
# 38.8    1
# 11.7    1
# 0.3     1
# 14.8    1
# Name: deciviews, Length: 231, dtype: int64
#
# Column: deciviews_a
# 17.0    8
# 20.8    7
# 17.4    7
# 19.7    7
# 16.8    6
#        ..
# 10.5    1
# 9.5     1
# 8.5     1
# 1.3     1
# 22.0    1
# Name: deciviews_a, Length: 237, dtype: int64
#
# Column: visual_range
# 79.6     4
# 40.1     4
# 41.4     3
# 41.1     3
# 48.5     3
#         ..
# 169.2    1
# 48.9     1
# 371.9    1
# 239.8    1
# 88.5     1
# Name: visual_range, Length: 474, dtype: int64
#
# Column: visual_range_a
# 41.3     4
# 48.7     3
# 62.4     3
# 345.3    3
# 289.4    2
#         ..
# 182.9    1
# 35.6     1
# 67.9     1
# 100.2    1
# 86.2     1
# Name: visual_range_a, Length: 473, dtype: int64
#
# Column: 0.3_um_count
# 0       15
# 258      3
# 166      3
# 2513     2
# 697      2
#         ..
# 743      1
# 3872     1
# 27       1
# 348      1
# 126      1
# Name: 0.3_um_count, Length: 558, dtype: int64
#
# Column: 0.3_um_count_a
# 0       16
# 122      3
# 72       3
# 255      2
# 159      2
#         ..
# 27       1
# 348      1
# 561      1
# 1918     1
# 1958     1
# Name: 0.3_um_count_a, Length: 562, dtype: int64
#
# Column: 0.5_um_count
# 0       16
# 61       6
# 16       5
# 33       4
# 8        4
#         ..
# 531      1
# 1521     1
# 596      1
# 6687     1
# 548      1
# Name: 0.5_um_count, Length: 462, dtype: int64
#
# Column: 0.5_um_count_a
# 0       17
# 16       5
# 18       5
# 61       4
# 41       4
#         ..
# 876      1
# 1019     1
# 1601     1
# 431      1
# 558      1
# Name: 0.5_um_count_a, Length: 464, dtype: int64
#
# Column: 1.0_um_count
# 0      34
# 3      16
# 5      15
# 6      15
# 1      11
#        ..
# 189     1
# 159     1
# 33      1
# 168     1
# 119     1
# Name: 1.0_um_count, Length: 241, dtype: int64
#
# Column: 1.0_um_count_a
# 0      33
# 5      17
# 3      15
# 6      13
# 2      10
#        ..
# 112     1
# 282     1
# 103     1
# 105     1
# 191     1
# Name: 1.0_um_count_a, Length: 235, dtype: int64
#
# Column: 2.5_um_count
# 0     187
# 1      57
# 2      42
# 13     21
# 6      20
# 3      18
# 12     18
# 4      15
# 11     15
# 16     15
# 15     14
# 10     14
# 8      12
# 9      11
# 7      11
# 14     11
# 18     10
# 19     10
# 22      9
# 23      9
# 32      8
# 26      8
# 17      8
# 31      7
# 36      7
# 24      6
# 21      5
# 20      5
# 5       5
# 28      4
# 25      4
# 39      3
# 29      3
# 33      3
# 30      3
# 35      2
# 42      2
# 27      2
# 43      2
# 48      1
# 81      1
# 65      1
# 49      1
# 51      1
# 68      1
# 38      1
# 34      1
# 37      1
# 45      1
# Name: 2.5_um_count, dtype: int64
#
# Column: 2.5_um_count_a
# 0     184
# 1      52
# 2      37
# 3      27
# 10     21
# 13     18
# 4      17
# 11     17
# 7      16
# 15     15
# 8      14
# 6      13
# 14     13
# 19     11
# 20     10
# 5      10
# 9      10
# 12      9
# 24      9
# 22      8
# 16      8
# 18      8
# 27      7
# 17      7
# 30      7
# 21      6
# 23      5
# 25      5
# 28      5
# 31      5
# 39      4
# 35      4
# 34      3
# 26      3
# 33      3
# 29      3
# 37      3
# 43      3
# 42      2
# 32      2
# 46      2
# 36      2
# 52      1
# 48      1
# 68      1
# 65      1
# 44      1
# 47      1
# 45      1
# 38      1
# Name: 2.5_um_count_a, dtype: int64
#
# Column: 5.0_um_count
# 0      311
# 1       78
# 2       51
# 3       43
# 4       37
# 5       21
# 6       16
# 7       14
# 11       8
# 9        7
# 8        7
# 15       4
# 12       3
# 14       3
# 16       2
# 10       2
# 134      1
# 127      1
# 27       1
# 23       1
# 123      1
# 132      1
# 21       1
# 17       1
# 26       1
# Name: 5.0_um_count, dtype: int64
#
# Column: 5.0_um_count_a
# 0      294
# 1       88
# 2       61
# 3       53
# 6       24
# 4       22
# 5       19
# 7       11
# 8        7
# 9        6
# 15       5
# 11       4
# 10       3
# 12       2
# 21       2
# 131      2
# 22       2
# 20       2
# 17       1
# 16       1
# 18       1
# 13       1
# 124      1
# 23       1
# 121      1
# 27       1
# 14       1
# Name: 5.0_um_count_a, dtype: int64
#
# Column: 10.0_um_count
# 0      485
# 1       63
# 2       30
# 3       10
# 4        9
# 9        4
# 10       3
# 5        2
# 6        1
# 14       1
# 21       1
# 8        1
# 7        1
# 332      1
# 346      1
# 359      1
# 335      1
# 15       1
# Name: 10.0_um_count, dtype: int64
#
# Column: 10.0_um_count_a
# 0      469
# 1       71
# 2       33
# 3       17
# 4        8
# 6        3
# 8        2
# 351      1
# 338      1
# 364      1
# 21       1
# 334      1
# 15       1
# 10       1
# 9        1
# 18       1
# 5        1
# 7        1
# 13       1
# 20       1
# Name: 10.0_um_count_a, dtype: int64
#
# Column: pm1.0_cf_1
# 0.0     108
# 0.2      15
# 0.1       9
# 0.8       7
# 2.9       7
#        ...
# 29.3      1
# 8.8       1
# 17.5      1
# 33.3      1
# 13.3      1
# Name: pm1.0_cf_1, Length: 251, dtype: int64
#
# Column: pm1.0_cf_1_a
# 0.00     97
# 0.21      4
# 0.04      3
# 2.33      3
# 0.28      3
#          ..
# 11.61     1
# 2.89      1
# 16.66     1
# 0.72      1
# 10.44     1
# Name: pm1.0_cf_1_a, Length: 468, dtype: int64
#
# Column: pm1.0_atm
# 0.0     108
# 0.2      15
# 0.1       9
# 0.8       7
# 2.9       7
#        ...
# 26.6      1
# 22.5      1
# 27.5      1
# 24.5      1
# 13.3      1
# Name: pm1.0_atm, Length: 232, dtype: int64
#
# Column: pm1.0_atm_a
# 0.00     97
# 0.21      4
# 0.28      3
# 0.04      3
# 0.02      3
#          ..
# 18.83     1
# 1.09      1
# 12.20     1
# 16.47     1
# 10.44     1
# Name: pm1.0_atm_a, Length: 468, dtype: int64
#
# Column: pm2.5_atm
# 0.0     70
# 0.1     11
# 0.2     11
# 0.4      9
# 1.0      8
#         ..
# 27.4     1
# 26.1     1
# 44.6     1
# 5.6      1
# 14.5     1
# Name: pm2.5_atm, Length: 295, dtype: int64
#
# Column: pm2.5_atm_a
# 0.00     58
# 0.04      6
# 0.02      3
# 4.40      3
# 0.20      3
#          ..
# 43.28     1
# 3.27      1
# 0.11      1
# 36.96     1
# 13.95     1
# Name: pm2.5_atm_a, Length: 514, dtype: int64
#
# Column: pm2.5_cf_1
# 0.0     70
# 0.2     11
# 0.1     11
# 0.4      9
# 1.0      8
#         ..
# 4.6      1
# 32.0     1
# 32.4     1
# 34.7     1
# 14.5     1
# Name: pm2.5_cf_1, Length: 308, dtype: int64
#
# Column: pm2.5_cf_1_a
# 0.00     58
# 0.04      6
# 0.02      3
# 0.20      3
# 4.40      3
#          ..
# 0.76      1
# 17.93     1
# 51.54     1
# 3.27      1
# 13.95     1
# Name: pm2.5_cf_1_a, Length: 512, dtype: int64
#
# Column: pm10.0_atm
# 0.0     55
# 0.4     13
# 0.2     12
# 0.1     11
# 0.3      8
#         ..
# 5.5      1
# 38.8     1
# 45.8     1
# 25.5     1
# 16.9     1
# Name: pm10.0_atm, Length: 320, dtype: int64
#
# Column: pm10.0_atm_a
# 0.00     47
# 0.41      4
# 1.35      3
# 0.10      3
# 0.53      3
#          ..
# 19.00     1
# 54.42     1
# 3.45      1
# 52.12     1
# 0.09      1
# Name: pm10.0_atm_a, Length: 516, dtype: int64
#
# Column: pm10.0_cf_1
# 0.0     55
# 0.4     13
# 0.2     12
# 0.1     11
# 0.3      8
#         ..
# 45.0     1
# 46.8     1
# 25.5     1
# 51.0     1
# 16.9     1
# Name: pm10.0_cf_1, Length: 321, dtype: int64
#
# Column: pm10.0_cf_1_a
# 0.00     47
# 0.41      4
# 1.35      3
# 18.76     3
# 0.53      3
#          ..
# 3.45      1
# 56.61     1
# 26.65     1
# 17.25     1
# 0.09      1
# Name: pm10.0_cf_1_a, Length: 515, dtype: int64
#
# Column: primary_id_a
# 84144.0      1
# 1420451.0    1
# 1352022.0    1
# 1365296.0    1
# 1369585.0    1
#             ..
# 658723.0     1
# 660357.0     1
# 663430.0     1
# 663544.0     1
# 2186572.0    1
# Name: primary_id_a, Length: 586, dtype: int64
#
# Column: primary_key_a
# DYBYPI2LSK4QGFNM    1
# 0SJCDK4O5TIBANOJ    1
# 3U4GL9HHDG0L4QNA    1
# OOOUEYZSMAYA8ODC    1
# 9H8UC9SQC9TW54KS    1
#                    ..
# C82DOU7P90GGFLG2    1
# 1STOMIECVC3TKPF9    1
# 9MRSLHP04ITHKZIP    1
# NXBA5QKRILOB1KE6    1
# JFB1W3HWRUNEVT52    1
# Name: primary_key_a, Length: 616, dtype: int64
#
# Column: primary_id_b
# 725391.0     1
# 1420453.0    1
# 1352024.0    1
# 1365298.0    1
# 1369587.0    1
#             ..
# 658726.0     1
# 660359.0     1
# 663432.0     1
# 663546.0     1
# 2186576.0    1
# Name: primary_id_b, Length: 586, dtype: int64
#
# Column: primary_key_b
# DGNHAFD7NZV9H2RZ    1
# EGW6F3HW4YHGWUS3    1
# 89OG3T81LKIIMRA3    1
# 6JOQ4KWSS7ZRJCF7    1
# 93G4LF8M0TJ4MLRE    1
#                    ..
# 19C47GAYDIE0N6KK    1
# TTBGALVWEDVMYQU0    1
# 7HWE7SF7TQOYYOX3    1
# 57ZIOJ4LF4OH0HGE    1
# G4R064HSLTRR8HM1    1
# Name: primary_key_b, Length: 586, dtype: int64
#
# Column: secondary_id_a
# 84145.0      1
# 1420452.0    1
# 1352023.0    1
# 1365297.0    1
# 1369586.0    1
#             ..
# 658725.0     1
# 660358.0     1
# 663431.0     1
# 663545.0     1
# 2186574.0    1
# Name: secondary_id_a, Length: 586, dtype: int64
#
# Column: secondary_key_a
# ITY12CRN3H8KPBJY    1
# 0QBWP6Y0M2I9A8ZB    1
# QGNUSKA4MAWGM0N2    1
# 8AIN85QY754O6UOB    1
# 8FXPG94BQU3IIN2B    1
#                    ..
# QY6XFBJM2R831ZTU    1
# 4NH5ZIFKCCFPKUSH    1
# 0ER8CVM1KXTSA5TZ    1
# AB1EHMXO2XUTMIVN    1
# 3EIGHRRBAFVVIPFA    1
# Name: secondary_key_a, Length: 586, dtype: int64
#
# Column: secondary_id_b
# 725392.0     1
# 1420454.0    1
# 1352026.0    1
# 1365299.0    1
# 1369588.0    1
#             ..
# 658727.0     1
# 660360.0     1
# 663433.0     1
# 663547.0     1
# 2186578.0    1
# Name: secondary_id_b, Length: 586, dtype: int64
#
# Column: secondary_key_b
# EB6SJL8KOR7K7WCA    1
# 95EAI8ESWOSPJFVZ    1
# 7GUDOPYWNCHJQ2R6    1
# UNNQTQ31QNQQR1XX    1
# 6XO7G4XBXS9E5MX0    1
#                    ..
# 5MJEK4LF5XSICJ6S    1
# WUIG3JPKGTPKW451    1
# 04R25ESWXDV9UFSM    1
# OGYBMH7DTICL1GTD    1
# DPRV5NVMX1LB9LKN    1
# Name: secondary_key_b, Length: 586, dtype: int64
#
# Column: stats
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 0.0, 'pm2.5_24hour': 0.0, 'pm2.5_1week': 0.0, 'time_stamp': 1706641157}           2
# {'pm2.5': 0.6, 'pm2.5_10minute': 0.4, 'pm2.5_30minute': 0.2, 'pm2.5_60minute': 0.2, 'pm2.5_6hour': 0.4, 'pm2.5_24hour': 0.5, 'pm2.5_1week': 0.5, 'time_stamp': 1706641173}           1
# {'pm2.5': 27.2, 'pm2.5_10minute': 29.8, 'pm2.5_30minute': 29.2, 'pm2.5_60minute': 26.0, 'pm2.5_6hour': 18.6, 'pm2.5_24hour': 14.1, 'pm2.5_1week': 7.1, 'time_stamp': 1706641116}     1
# {'pm2.5': 4.9, 'pm2.5_10minute': 8.2, 'pm2.5_30minute': 18.2, 'pm2.5_60minute': 31.0, 'pm2.5_6hour': 26.0, 'pm2.5_24hour': 15.5, 'pm2.5_1week': 10.5, 'time_stamp': 1706641222}      1
# {'pm2.5': 0.2, 'pm2.5_10minute': 0.1, 'pm2.5_30minute': 0.1, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 0.2, 'pm2.5_24hour': 0.3, 'pm2.5_1week': 0.8, 'time_stamp': 1706641222}           1
#                                                                                                                                                                                     ..
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.2, 'pm2.5_6hour': 4.4, 'pm2.5_24hour': 4.6, 'pm2.5_1week': 3.8, 'time_stamp': 1706637895}           1
# {'pm2.5': 29.7, 'pm2.5_10minute': 35.8, 'pm2.5_30minute': 39.5, 'pm2.5_60minute': 39.2, 'pm2.5_6hour': 30.6, 'pm2.5_24hour': 23.0, 'pm2.5_1week': 13.4, 'time_stamp': 1706641204}    1
# {'pm2.5': 4.1, 'pm2.5_10minute': 3.7, 'pm2.5_30minute': 3.7, 'pm2.5_60minute': 3.2, 'pm2.5_6hour': 2.3, 'pm2.5_24hour': 1.9, 'pm2.5_1week': 1.7, 'time_stamp': 1706641202}           1
# {'pm2.5': 30.7, 'pm2.5_10minute': 31.9, 'pm2.5_30minute': 33.4, 'pm2.5_60minute': 33.8, 'pm2.5_6hour': 28.2, 'pm2.5_24hour': 21.0, 'pm2.5_1week': 12.6, 'time_stamp': 1706641178}    1
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 2.2, 'pm2.5_24hour': 5.3, 'pm2.5_1week': 1.6, 'time_stamp': 1706641272}           1
# Name: stats, Length: 615, dtype: int64
#
# Column: stats_a
# {'pm2.5': 0.6, 'pm2.5_10minute': 0.4, 'pm2.5_30minute': 0.2, 'pm2.5_60minute': 0.2, 'pm2.5_6hour': 0.4, 'pm2.5_24hour': 0.5, 'pm2.5_1week': 0.5, 'time_stamp': 1706641173}           1
# {'pm2.5': 15.6, 'pm2.5_10minute': 16.7, 'pm2.5_30minute': 17.2, 'pm2.5_60minute': 15.5, 'pm2.5_6hour': 8.8, 'pm2.5_24hour': 11.0, 'pm2.5_1week': 11.8, 'time_stamp': 1706641192}     1
# {'pm2.5': 0.9, 'pm2.5_10minute': 0.9, 'pm2.5_30minute': 0.8, 'pm2.5_60minute': 0.7, 'pm2.5_6hour': 1.7, 'pm2.5_24hour': 12.7, 'pm2.5_1week': 8.0, 'time_stamp': 1706641283}          1
# {'pm2.5': 5.9, 'pm2.5_10minute': 8.8, 'pm2.5_30minute': 24.8, 'pm2.5_60minute': 47.0, 'pm2.5_6hour': 40.8, 'pm2.5_24hour': 22.3, 'pm2.5_1week': 13.8, 'time_stamp': 1706641222}      1
# {'pm2.5': 0.4, 'pm2.5_10minute': 0.2, 'pm2.5_30minute': 0.2, 'pm2.5_60minute': 0.1, 'pm2.5_6hour': 0.2, 'pm2.5_24hour': 0.4, 'pm2.5_1week': 1.0, 'time_stamp': 1706641222}           1
#                                                                                                                                                                                     ..
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 0.0, 'pm2.5_24hour': 0.0, 'pm2.5_1week': 0.1, 'time_stamp': 1706641214}           1
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.2, 'pm2.5_6hour': 5.3, 'pm2.5_24hour': 5.7, 'pm2.5_1week': 5.0, 'time_stamp': 1706637895}           1
# {'pm2.5': 29.0, 'pm2.5_10minute': 34.9, 'pm2.5_30minute': 38.7, 'pm2.5_60minute': 38.5, 'pm2.5_6hour': 30.7, 'pm2.5_24hour': 23.3, 'pm2.5_1week': 14.0, 'time_stamp': 1706641204}    1
# {'pm2.5': 4.1, 'pm2.5_10minute': 3.7, 'pm2.5_30minute': 3.7, 'pm2.5_60minute': 3.2, 'pm2.5_6hour': 2.3, 'pm2.5_24hour': 1.9, 'pm2.5_1week': 1.7, 'time_stamp': 1706641202}           1
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 2.2, 'pm2.5_24hour': 5.2, 'pm2.5_1week': 1.5, 'time_stamp': 1706641272}           1
# Name: stats_a, Length: 616, dtype: int64
#
# Column: confidence_auto
# 100.0    379
# 0.0       46
# 1.0        5
# 97.0       4
# 98.0       3
# 82.0       3
# 94.0       3
# 60.0       2
# 85.0       2
# 84.0       2
# 83.0       2
# 99.0       2
# 92.0       2
# 96.0       2
# 77.0       2
# 37.0       1
# 89.0       1
# 40.0       1
# 63.0       1
# 79.0       1
# 13.0       1
# 66.0       1
# 48.0       1
# 95.0       1
# 54.0       1
# 72.0       1
# 6.0        1
# 2.0        1
# 42.0       1
# 5.0        1
# 4.0        1
# 91.0       1
# 57.0       1
# 23.0       1
# 7.0        1
# 36.0       1
# 87.0       1
# 9.0        1
# 61.0       1
# 80.0       1
# 69.0       1
# 73.0       1
# 52.0       1
# Name: confidence_auto, dtype: int64
#
# Column: confidence_manual
# 100.0    370
# 0.0       44
# 60.0      11
# 97.0       4
# 94.0       3
# 98.0       3
# 82.0       3
# 1.0        3
# 3.0        2
# 84.0       2
# 96.0       2
# 83.0       2
# 85.0       2
# 2.0        2
# 92.0       2
# 99.0       2
# 9.0        2
# 77.0       2
# 12.0       1
# 79.0       1
# 54.0       1
# 95.0       1
# 63.0       1
# 72.0       1
# 48.0       1
# 66.0       1
# 37.0       1
# 89.0       1
# 40.0       1
# 11.0       1
# 69.0       1
# 73.0       1
# 13.0       1
# 23.0       1
# 25.0       1
# 80.0       1
# 61.0       1
# 4.0        1
# 87.0       1
# 8.0        1
# 36.0       1
# 91.0       1
# 57.0       1
# 52.0       1
# Name: confidence_manual, dtype: int64
#
# Column: humidity
# 34.0    22
# 26.0    21
# 23.0    20
# 38.0    19
# 42.0    19
#         ..
# 51.0     1
# 93.0     1
# 71.0     1
# 94.0     1
# 11.0     1
# Name: humidity, Length: 73, dtype: int64
#
# Column: humidity_a
# 26.0    21
# 34.0    21
# 23.0    19
# 38.0    19
# 42.0    19
#         ..
# 75.0     1
# 93.0     1
# 71.0     1
# 94.0     1
# 11.0     1
# Name: humidity_a, Length: 72, dtype: int64
#
# Column: temperature
# 56.0     25
# 57.0     24
# 54.0     22
# 79.0     22
# 52.0     22
#          ..
# 95.0      1
# 105.0     1
# 45.0      1
# 123.0     1
# 33.0      1
# Name: temperature, Length: 62, dtype: int64
#
# Column: temperature_a
# 56.0     25
# 57.0     24
# 52.0     23
# 54.0     22
# 79.0     22
#          ..
# 95.0      1
# 105.0     1
# 45.0      1
# 123.0     1
# 39.0      1
# Name: temperature_a, Length: 62, dtype: int64
#
# Column: pressure
# 874.99    3
# 875.24    2
# 875.10    2
# 875.48    2
# 851.90    2
#          ..
# 878.73    1
# 876.83    1
# 875.01    1
# 831.05    1
# 802.22    1
# Name: pressure, Length: 542, dtype: int64
#
# Column: pressure_a
# 874.99    3
# 875.24    2
# 875.10    2
# 875.48    2
# 850.44    2
#          ..
# 876.83    1
# 875.01    1
# 831.05    1
# 877.51    1
# 802.22    1
# Name: pressure_a, Length: 542, dtype: int64
#
# Column: pm1.0_b
# 0.0     51
# 2.8      7
# 9.6      6
# 5.1      5
# 18.0     5
#         ..
# 26.0     1
# 4.4      1
# 6.2      1
# 5.8      1
# 19.7     1
# Name: pm1.0_b, Length: 238, dtype: int64
#
# Column: pm2.5_b
# 0.0       37
# 4.0        6
# 22.5       5
# 1.1        5
# 29.7       5
#           ..
# 3509.7     1
# 26.7       1
# 25.6       1
# 20.1       1
# 15.0       1
# Name: pm2.5_b, Length: 281, dtype: int64
#
# Column: pm2.5_alt_b
# 0.0     21
# 2.2      8
# 2.0      6
# 0.3      6
# 0.7      6
#         ..
# 24.3     1
# 8.7      1
# 24.7     1
# 22.6     1
# 9.0      1
# Name: pm2.5_alt_b, Length: 227, dtype: int64
#
# Column: pm10.0_b
# 0.0     31
# 0.1      5
# 3.8      4
# 18.2     4
# 28.3     4
#         ..
# 98.5     1
# 16.5     1
# 48.2     1
# 52.0     1
# 15.8     1
# Name: pm10.0_b, Length: 304, dtype: int64
#
# Column: scattering_coefficient_b
# 9.6     4
# 44.5    3
# 8.9     3
# 3.2     3
# 29.8    3
#        ..
# 27.4    1
# 71.1    1
# 29.6    1
# 36.7    1
# 1.4     1
# Name: scattering_coefficient_b, Length: 335, dtype: int64
#
# Column: deciviews_b
# 19.3    9
# 15.2    7
# 18.7    6
# 18.5    6
# 20.7    5
#        ..
# 2.3     1
# 7.2     1
# 5.4     1
# 25.4    1
# 1.6     1
# Name: deciviews_b, Length: 205, dtype: int64
#
# Column: visual_range_b
# 56.5     4
# 61.5     3
# 71.8     3
# 41.8     3
# 59.9     2
#         ..
# 94.5     1
# 33.9     1
# 203.1    1
# 109.0    1
# 333.6    1
# Name: visual_range_b, Length: 361, dtype: int64
#
# Column: 0.3_um_count_b
# 0.0       20
# 2073.0     3
# 2968.0     2
# 75.0       2
# 1708.0     2
#           ..
# 3106.0     1
# 3680.0     1
# 6332.0     1
# 3156.0     1
# 94.0       1
# Name: 0.3_um_count_b, Length: 445, dtype: int64
#
# Column: 0.5_um_count_b
# 0.0       20
# 178.0      3
# 799.0      3
# 865.0      3
# 22.0       3
#           ..
# 778.0      1
# 236.0      1
# 1065.0     1
# 114.0      1
# 812.0      1
# Name: 0.5_um_count_b, Length: 405, dtype: int64
#
# Column: 1.0_um_count_b
# 0.0      32
# 1.0       7
# 131.0     7
# 99.0      6
# 19.0      6
#          ..
# 46.0      1
# 128.0     1
# 151.0     1
# 74.0      1
# 83.0      1
# Name: 1.0_um_count_b, Length: 223, dtype: int64
#
# Column: 2.5_um_count_b
# 0.0      116
# 1.0       36
# 3.0       21
# 13.0      20
# 2.0       19
# 8.0       18
# 5.0       16
# 16.0      14
# 4.0       14
# 7.0       13
# 10.0      12
# 12.0      12
# 14.0      12
# 9.0       11
# 17.0      11
# 11.0      11
# 15.0      10
# 6.0       10
# 19.0       9
# 32.0       8
# 29.0       7
# 18.0       7
# 20.0       7
# 23.0       6
# 25.0       6
# 24.0       6
# 21.0       5
# 31.0       4
# 22.0       4
# 28.0       4
# 26.0       4
# 30.0       4
# 37.0       3
# 39.0       3
# 36.0       3
# 27.0       3
# 42.0       2
# 33.0       2
# 47.0       2
# 43.0       2
# 38.0       1
# 50.0       1
# 143.0      1
# 56.0       1
# 52.0       1
# 44.0       1
# 41.0       1
# 40.0       1
# 35.0       1
# 34.0       1
# Name: 2.5_um_count_b, dtype: int64
#
# Column: 5.0_um_count_b
# 0.0      201
# 1.0       77
# 2.0       43
# 3.0       43
# 4.0       33
# 5.0       22
# 6.0       12
# 8.0       11
# 7.0       11
# 9.0        8
# 12.0       3
# 13.0       3
# 11.0       3
# 20.0       2
# 14.0       2
# 17.0       2
# 10.0       2
# 131.0      1
# 133.0      1
# 21.0       1
# 19.0       1
# 125.0      1
# 24.0       1
# 18.0       1
# 50.0       1
# 137.0      1
# Name: 5.0_um_count_b, dtype: int64
#
# Column: 10.0_um_count_b
# 0.0      350
# 1.0       72
# 2.0       29
# 3.0        7
# 4.0        7
# 7.0        4
# 5.0        3
# 6.0        3
# 9.0        2
# 10.0       2
# 327.0      1
# 341.0      1
# 354.0      1
# 337.0      1
# 18.0       1
# 17.0       1
# 12.0       1
# 28.0       1
# Name: 10.0_um_count_b, dtype: int64
#
# Column: pm1.0_cf_1_b
# 0.00     50
# 2.53      3
# 21.91     3
# 18.71     2
# 2.76      2
#          ..
# 44.19     1
# 7.83      1
# 16.67     1
# 23.07     1
# 10.05     1
# Name: pm1.0_cf_1_b, Length: 410, dtype: int64
#
# Column: pm1.0_atm_b
# 0.00     50
# 22.07     3
# 2.53      3
# 7.48      2
# 2.37      2
#          ..
# 35.48     1
# 7.83      1
# 16.67     1
# 20.32     1
# 10.05     1
# Name: pm1.0_atm_b, Length: 408, dtype: int64
#
# Column: pm2.5_atm_b
# 0.00       35
# 1.11        3
# 38.02       3
# 15.54       2
# 19.79       2
#            ..
# 39.69       1
# 18.91       1
# 3327.04     1
# 46.84       1
# 14.98       1
# Name: pm2.5_atm_b, Length: 422, dtype: int64
#
# Column: pm2.5_cf_1_b
# 0.00       35
# 1.11        3
# 0.23        2
# 0.05        2
# 0.47        2
#            ..
# 18.91       1
# 4991.37     1
# 36.09       1
# 53.60       1
# 14.98       1
# Name: pm2.5_cf_1_b, Length: 429, dtype: int64
#
# Column: pm10.0_atm_b
# 0.00     31
# 22.91     2
# 26.05     2
# 39.14     2
# 34.12     2
#          ..
# 66.31     1
# 12.97     1
# 30.63     1
# 39.02     1
# 15.80     1
# Name: pm10.0_atm_b, Length: 436, dtype: int64
#
# Column: pm10.0_cf_1_b
# 0.00     31
# 4.65      2
# 19.32     2
# 34.12     2
# 48.05     2
#          ..
# 39.73     1
# 72.21     1
# 12.97     1
# 30.63     1
# 15.80     1
# Name: pm10.0_cf_1_b, Length: 439, dtype: int64
#
# Column: stats_b
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 0.0, 'pm2.5_24hour': 0.0, 'pm2.5_1week': 0.0, 'time_stamp': 1706641157}           2
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 0.0, 'pm2.5_24hour': 0.0, 'pm2.5_1week': 0.0, 'time_stamp': 1706641168}           2
# {'pm2.5': 9.8, 'pm2.5_10minute': 7.8, 'pm2.5_30minute': 9.0, 'pm2.5_60minute': 10.9, 'pm2.5_6hour': 19.5, 'pm2.5_24hour': 24.7, 'pm2.5_1week': 22.1, 'time_stamp': 1706641080}       1
# {'pm2.5': 66.6, 'pm2.5_10minute': 64.2, 'pm2.5_30minute': 63.1, 'pm2.5_60minute': 66.9, 'pm2.5_6hour': 74.9, 'pm2.5_24hour': 57.2, 'pm2.5_1week': 38.2, 'time_stamp': 1706641212}    1
# {'pm2.5': 0.4, 'pm2.5_10minute': 0.1, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.0, 'pm2.5_6hour': 0.8, 'pm2.5_24hour': 4.7, 'pm2.5_1week': 4.2, 'time_stamp': 1706641260}           1
#                                                                                                                                                                                     ..
# {'pm2.5': 29.1, 'pm2.5_10minute': 28.7, 'pm2.5_30minute': 24.5, 'pm2.5_60minute': 21.6, 'pm2.5_6hour': 18.4, 'pm2.5_24hour': 17.8, 'pm2.5_1week': 16.0, 'time_stamp': 1706641221}    1
# {'pm2.5': 32.5, 'pm2.5_10minute': 33.6, 'pm2.5_30minute': 34.4, 'pm2.5_60minute': 32.9, 'pm2.5_6hour': 26.5, 'pm2.5_24hour': 23.8, 'pm2.5_1week': 18.4, 'time_stamp': 1706641165}    1
# {'pm2.5': 2.8, 'pm2.5_10minute': 4.1, 'pm2.5_30minute': 5.1, 'pm2.5_60minute': 5.1, 'pm2.5_6hour': 6.7, 'pm2.5_24hour': 8.4, 'pm2.5_1week': 8.0, 'time_stamp': 1706641173}           1
# {'pm2.5': 0.2, 'pm2.5_10minute': 0.1, 'pm2.5_30minute': 0.1, 'pm2.5_60minute': 0.1, 'pm2.5_6hour': 0.2, 'pm2.5_24hour': 0.1, 'pm2.5_1week': 0.1, 'time_stamp': 1706641096}           1
# {'pm2.5': 0.0, 'pm2.5_10minute': 0.0, 'pm2.5_30minute': 0.0, 'pm2.5_60minute': 0.1, 'pm2.5_6hour': 2.3, 'pm2.5_24hour': 5.4, 'pm2.5_1week': 1.6, 'time_stamp': 1706641272}           1
# Name: stats_b, Length: 485, dtype: int64
#
# Column: altitude
# 4941.0    4
# 4583.0    4
# 4414.0    4
# 4739.0    4
# 4342.0    3
#          ..
# 4375.0    1
# 5109.0    1
# 4680.0    1
# 4225.0    1
# 6684.0    1
# Name: altitude, Length: 480, dtype: int64
#
# Column: ozone1
# 145.0    1
# Name: ozone1, dtype: int64
#
# Column: humidity_b
# 18.0    7
# 26.0    6
# 16.0    4
# 21.0    3
# 12.0    3
# 27.0    3
# 25.0    3
# 42.0    2
# 38.0    2
# 23.0    2
# 19.0    2
# 40.0    2
# 29.0    2
# 24.0    2
# 13.0    1
# 32.0    1
# 11.0    1
# 22.0    1
# 50.0    1
# 14.0    1
# 65.0    1
# 33.0    1
# 30.0    1
# 20.0    1
# 41.0    1
# 37.0    1
# 28.0    1
# Name: humidity_b, dtype: int64
#
# Column: temperature_b
# 93.0    5
# 85.0    4
# 61.0    3
# 87.0    3
# 65.0    3
# 59.0    2
# 67.0    2
# 49.0    2
# 86.0    2
# 74.0    2
# 90.0    2
# 88.0    2
# 69.0    2
# 66.0    2
# 60.0    2
# 62.0    1
# 68.0    1
# 79.0    1
# 78.0    1
# 83.0    1
# 48.0    1
# 53.0    1
# 71.0    1
# 56.0    1
# 63.0    1
# 91.0    1
# 43.0    1
# 57.0    1
# 58.0    1
# 81.0    1
# 84.0    1
# 72.0    1
# 52.0    1
# Name: temperature_b, dtype: int64
#
# Column: pressure_b
# 849.05    2
# 870.06    1
# 868.10    1
# 877.43    1
# 798.95    1
# 868.11    1
# 824.33    1
# 854.79    1
# 875.89    1
# 823.79    1
# 856.08    1
# 853.15    1
# 880.02    1
# 866.59    1
# 876.11    1
# 798.91    1
# 868.79    1
# 878.88    1
# 869.97    1
# 864.41    1
# 855.98    1
# 868.40    1
# 854.43    1
# 852.63    1
# 809.31    1
# 863.90    1
# 823.86    1
# 879.60    1
# 858.40    1
# 869.00    1
# 864.01    1
# 849.44    1
# 849.74    1
# 848.94    1
# 863.30    1
# 872.86    1
# 821.36    1
# 863.07    1
# 867.60    1
# 868.45    1
# 851.41    1
# 879.13    1
# 872.08    1
# 850.37    1
# 849.36    1
# 864.57    1
# 875.56    1
# 876.54    1
# 870.79    1
# 873.71    1
# 846.50    1
# 855.56    1
# 868.61    1
# 866.30    1
# 802.22    1
# Name: pressure_b, dtype: int64
#
# Column: voc
# 50.8     2
# 51.6     2
# 65.9     2
# 71.0     1
# 55.5     1
# 175.5    1
# 78.5     1
# 451.4    1
# 154.7    1
# 90.2     1
# 66.2     1
# 76.5     1
# 57.1     1
# 264.1    1
# 107.8    1
# 106.3    1
# 56.4     1
# 147.8    1
# 170.8    1
# 66.5     1
# 73.9     1
# 56.3     1
# 54.6     1
# 58.6     1
# 78.9     1
# 67.5     1
# 60.9     1
# 142.6    1
# 65.7     1
# 59.5     1
# 50.1     1
# 55.2     1
# 102.3    1
# 115.0    1
# 65.5     1
# 61.5     1
# 129.7    1
# 427.0    1
# 85.8     1
# 50.0     1
# 53.7     1
# 62.6     1
# 323.5    1
# 73.3     1
# 495.4    1
# 51.2     1
# 65.1     1
# 532.4    1
# 156.7    1
# 114.4    1
# 105.7    1
# 100.4    1
# 50.6     1
# Name: voc, dtype: int64
#
# Column: voc_b
# 50.77     2
# 51.60     2
# 70.99     1
# 56.36     1
# 175.47    1
# 78.54     1
# 451.38    1
# 154.70    1
# 90.19     1
# 66.25     1
# 76.46     1
# 57.11     1
# 264.07    1
# 107.78    1
# 55.54     1
# 106.26    1
# 147.80    1
# 170.78    1
# 65.89     1
# 66.50     1
# 73.92     1
# 56.27     1
# 54.60     1
# 58.62     1
# 78.94     1
# 67.51     1
# 65.88     1
# 60.91     1
# 65.72     1
# 62.64     1
# 59.54     1
# 50.11     1
# 55.18     1
# 102.31    1
# 114.99    1
# 65.51     1
# 61.48     1
# 129.70    1
# 427.05    1
# 85.85     1
# 50.00     1
# 53.74     1
# 142.64    1
# 323.51    1
# 73.29     1
# 495.40    1
# 51.20     1
# 65.12     1
# 532.37    1
# 156.74    1
# 114.39    1
# 105.72    1
# 100.43    1
# 50.65     1
# Name: voc_b, dtype: int64

# %%
slc_sensor_eda['last_modified'] = pd.to_datetime(slc_sensor_eda['last_modified'], unit='s')
slc_sensor_eda['date_created'] = pd.to_datetime(slc_sensor_eda['date_created'], unit='s')
slc_sensor_eda['last_seen'] = pd.to_datetime(slc_sensor_eda['last_seen'], unit='s')

slc_sensor_eda.head()
# Out:
#    Unnamed: 0  sensor_index       last_modified        date_created  \
# 0           0            53 2018-03-02 21:26:22 2016-02-04 01:21:31
# 1           1            77 2019-11-30 00:48:27 2016-03-02 05:25:39
# 2           2            81 2016-06-11 21:24:52 2016-06-11 15:00:00
# 3           3           443 2019-06-08 04:01:48 2016-11-07 04:11:04
# 4           4           459 2022-05-29 03:50:54 2016-11-07 18:32:48
#
#             last_seen  private  is_owner                               name  \
# 0 2024-01-30 18:59:33        0         0                          Lakeshore
# 1 2024-01-30 18:59:30        0         0                          Sunnyside
# 2 2024-01-30 18:59:22        0         0                   Sherwood Hills 2
# 3 2024-01-30 18:58:00        0         0  Weber-Morgan Health Department P1
# 4 2024-01-30 18:58:27        0         0                Flight Park North 2
#
#    icon  location_type  ... pm10.0_atm_b pm10.0_cf_1_b  \
# 0     0              0  ...          NaN           NaN
# 1     0              0  ...          NaN           NaN
# 2     0              0  ...          NaN           NaN
# 3     0              0  ...        10.02         10.02
# 4     0              0  ...         7.50          7.50
#
#                                              stats_b altitude  ozone1  \
# 0                                                NaN      NaN     NaN
# 1                                                NaN      NaN     NaN
# 2                                                NaN      NaN     NaN
# 3  {'pm2.5': 9.8, 'pm2.5_10minute': 7.8, 'pm2.5_3...      NaN     NaN
# 4  {'pm2.5': 6.8, 'pm2.5_10minute': 9.4, 'pm2.5_3...   5122.0     NaN
#
#    humidity_b  temperature_b  pressure_b  voc  voc_b
# 0         NaN            NaN         NaN  NaN    NaN
# 1         NaN            NaN         NaN  NaN    NaN
# 2         NaN            NaN         NaN  NaN    NaN
# 3         NaN            NaN         NaN  NaN    NaN
# 4         NaN            NaN         NaN  NaN    NaN
#
# [5 rows x 110 columns]

# %%
oldest_sensor = slc_sensor_eda['date_created'].min()
oldest_sensor
# Out:
# Timestamp('2016-02-04 01:21:31')
