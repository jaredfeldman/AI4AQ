# %% [markdown]
# Get only the facilities that we have diagnosis data for

# %%
import pandas as pd

# %%
diag = pd.read_csv("../../data/external/health/medicare-claims-weekly.csv")
facilities = pd.read_csv('../../data/external/health/UT_Facilities.csv')

# %%
diag.merge(facilities, on='PRVDR_NUM', how='left')
# Out:
#       patient_count related_diagnosis  claim_week  claim_year PRVDR_NUM  \
# 0                12      A_AB_COPD_DY           1        2018    460006
# 1                12      A_AB_COPD_DY           1        2020    460001
# 2                36      A_AB_COPD_DY           1        2022    460009
# 3                53      A_AB_COPD_DY           1        2021    460009
# 4                16      A_AB_COPD_DY           1        2021    460047
# ...             ...               ...         ...         ...       ...
# 2360             12      A_AB_COPD_DY          53        2020    460019
# 2361             12      A_AB_COPD_DY          53        2020    460021
# 2362             11      A_AB_COPD_DY          53        2020    46T003
# 2363             18      A_AB_COPD_DY          53        2020    460004
# 2364             36      A_AB_COPD_DY          53        2020    460009
#
#       PRVDR_STATE_CD       CITY_NAME  \
# 0                 46  SALT LAKE CITY
# ...

# %%
relevant_fac = facilities[facilities['PRVDR_NUM'].isin(diag['PRVDR_NUM'].unique())]
relevant_fac
# Out:
#           CITY_NAME                                           FAC_NAME  \
# 0             PROVO                               UTAH VALLEY HOSPITAL
# 1    SALT LAKE CITY                  SALT LAKE REGIONAL MEDICAL CENTER
# 2             OGDEN                                 MCKAY DEE HOSPITAL
# 3             OGDEN                      OGDEN REGIONAL MEDICAL CENTER
# 4    SALT LAKE CITY                                       LDS HOSPITAL
# 5        CEDAR CITY                                CEDAR CITY HOSPITAL
# 7    SALT LAKE CITY           UNIVERSITY OF UTAH HOSPITALS AND CLINICS
# 8            MURRAY                       INTERMOUNTAIN MEDICAL CENTER
# 9             PRICE                                CASTLEVIEW HOSPITAL
# 11           PAYSON                             MOUNTAIN VIEW HOSPITAL
# 12           TOOELE                       MOUNTAIN WEST MEDICAL CENTER
# 13            LOGAN                            LOGAN REGIONAL HOSPITAL
# ...

# %% [markdown]
# Looks like we have some facilities in the diagnosis data that aren't in the facilities data. ID those below

# %%
diag[~diag['PRVDR_NUM'].isin(facilities['PRVDR_NUM'])]
# Out:
#       patient_count related_diagnosis  claim_week  claim_year PRVDR_NUM  \
# 21               12      A_AB_COPD_DY           1        2018    461835
# 246              12      A_AB_COPD_DY           6        2020    461835
# 329              12      A_AB_COPD_DY           7        2022    463994
# 891              12      A_AB_COPD_DY          20        2022    460062
# 931              12            Emesis          21        2017    46T051
# 2309             12      A_AB_COPD_DY          51        2022    461835
# 2362             11      A_AB_COPD_DY          53        2020    46T003
#
#       PRVDR_STATE_CD
# 21                46
# 246               46
# 329               46
# 891               46
# 931               46
# 2309              46
# 2362              46

# %% [markdown]
# With Korin's guidance, we won't worry about the providers that have a T in their `PRVDR_NUM` if we can't easily find a match for them.
#
# Notes:
# * 461835 can't find
# * 463994 is Roosevelt, UT outside of our region of interest
# * 460062 is Spanish Fork, UT which we do want to present data for

# %% [markdown]
# Order the facilities by zip

# %%
relevant_fac = relevant_fac.sort_values('ZIP_CD').reset_index()
relevant_fac.head(60)
# Out:
#     index       CITY_NAME                                           FAC_NAME  \
# 0      21   AMERICAN FORK                             AMERICAN FORK HOSPITAL
# 1      37       BOUNTIFUL                                  LAKEVIEW HOSPITAL
# 2      55          DRAPER                                 LONE PEAK HOSPITAL
# 3      66      HEBER CITY                              HEBER VALLEY HOSPITAL
# 4      56          LAYTON                                    LAYTON HOSPITAL
    -109.48268532583184, # BLUE MOUNTAIN HOSPITAL
    -111.0212679630126, # EMERY MEDICAL CENTER
    -110.39345516963279, # CARBON MEDICAL SERVICE ASSOCIATION
    -109.55921918448252, # MOAB REGIONAL HOSPITAL
    #-109.30390343611786, # MONTEZUMA CREEK COMMUNITY HEALTH CENTER
    #-109.34981898604534, # SAN JUAN CLINIC
    -109.35017120513693, # SAN JUAN HOSPITAL
    -111.66843196280259, # UTAH VALLEY DIALYSIS CENTER
    -111.66573682063333, # UTAH VALLEY HOSPITAL
    -112.56111189680894, # DELTA COMMUNITY HOSPITAL
    -112.34040747651811, # FILLMORE COMMUNITY HOSPITAL
    -111.81647201513941, # GUNNISON VALLEY HOSPITAL
    -111.46102513231249, # SANPETE VALLEY HOSPITAL - CAH
    -111.83792824949417, # CENTRAL VALLEY MEDICAL CENTER - CAH
    -111.71470912900799, # UNIVERSITY OF UTAH PAYSON REGIONAL DIALYSIS CENTER
    -111.71448099180772, # MOUNTAIN VIEW HOSPITAL
    -111.6846310030603, # MT NEBO DIALYSIS
    -112.08554877837547, # MOUNTAIN UTAH FAMILY MEDICINE
    -112.08404550906, # SEVIER VALLEY HOSPITAL
    -112.64381270207824, # BEAVER VALLEY HOSPITAL
    -112.643765006956, # BEAVER MEDICAL CLINIC
    -111.55011025665439, # WAYNE COMMUNITY HEALTH CENTERS
    -113.06330427978851, # FRESENIUS MEDICAL CARE CEDAR CITY LLC
    -113.06660102630221, # CEDAR CITY HOSPITAL
    -112.5296166514696, # KANE COUNTY HOSPITAL
    -112.4270901075313, # GARFIELD MEMORIAL HOSPITAL
    #-112.42719403451795, # GARFIELD MEMORIAL CLINIC
    #-113.56278287475632, # LIBERTY DIALYSIS - ST GEORGE
    -113.58095054524522, # S W U C H C - SOUTHWEST UT COMMUNITY HEALTH CENTER
    -113.57575022018614 # DIXIE REGIONAL MEDICAL CENTER
])

# %%
assert(len(lat) == len(lon))

# %%
relevant_fac['lat'] = lat
relevant_fac['lon'] = lon

# %%
relevant_fac
# Out:
#     index       CITY_NAME                                           FAC_NAME  \
# 0      21   AMERICAN FORK                             AMERICAN FORK HOSPITAL
# 1      37       BOUNTIFUL                                  LAKEVIEW HOSPITAL
# 2      55          DRAPER                                 LONE PEAK HOSPITAL
# 3      66      HEBER CITY                              HEBER VALLEY HOSPITAL
# 4      56          LAYTON                                    LAYTON HOSPITAL
# 5      36          LAYTON                  DAVIS HOSPITAL AND MEDICAL CENTER
# 6      47            OREM                       TIMPANOGOS REGIONAL HOSPITAL
# 7      52       PARK CITY                                 PARK CITY HOSPITAL
# 8      53        RIVERTON                                  RIVERTON HOSPITAL
# 9      17       ROOSEVELT                        UINTAH BASIN MEDICAL CENTER
# 10     12          TOOELE                       MOUNTAIN WEST MEDICAL CENTER
# ...

# %% [markdown]
# Add back in the Spanish Fork facility we couldn't find earlier

# %%
diag[diag['PRVDR_NUM'].astype("string") == "460062"]
# Out:
#      patient_count related_diagnosis  claim_week  claim_year PRVDR_NUM  \
# 891             12      A_AB_COPD_DY          20        2022    460062
#
#      PRVDR_STATE_CD
# 891              46

# %%
save = relevant_fac.iloc[ :, 1:]

# %%
save.loc[len(save.index)] = ['SPANISH FORK', 'SPANISH FORK HOSPITAL', '460062', 'UT', 84660, 40.130694887524236, -111.64088972382105]

# %%
save.to_csv('../../data/processed/facility_locations_latlon.csv', index=False)
