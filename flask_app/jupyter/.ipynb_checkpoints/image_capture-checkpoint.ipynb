# %%
gdf = gpd.read_file('../static/data/centroids_data.geojson')

# %%
gdf
# Out:
#      OBJECTID         GEOID        county   Tract  Low Lowmod  Lowmod_pct  \
# 0      199060  490111251021  Davis County  125102  120    340      0.1833
# 1      199061  490111251022  Davis County  125102  245    490      0.1892
# 2      199062  490111251031  Davis County  125103  370    850      0.3131
# 3      199063  490111251032  Davis County  125103  430   1000      0.4264
# 4      199064  490111251041  Davis County  125104  165    475      0.1967
# ..        ...           ...           ...     ...  ...    ...         ...
# 907    200607  490572112012  Weber County  211201   70    170      0.1560
# 908    200608  490572112013  Weber County  211201  365    975      0.4194
# 909    200609  490572112021  Weber County  211202  115    270      0.3354
# 910    200610  490572112022  Weber County  211202  620   1710      0.3963
# 911    200611  490572112023  Weber County  211202  135    360      0.2637
#
#     category                     geometry
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import Point

# Assuming gdf is your GeoDataFrame loaded from 'centroids_data.geojson'

for index, row in gdf.iterrows():
    # Wrap the geometry in a GeoDataFrame
    temp_gdf = gpd.GeoDataFrame(index=[0], crs=gdf.crs, geometry=[row.geometry])
    
    # Project the temporary GeoDataFrame to Web Mercator
    temp_gdf = temp_gdf.to_crs(epsg=3857)
    
    # Now temp_gdf is in Web Mercator projection, you can plot it
    fig, ax = plt.subplots(figsize=(8, 8))
    temp_gdf.plot(ax=ax, color='red', markersize=50)
    
    # Determine the extent to zoom into, using the buffer method on the geometry
    # Adjust buffer_size to your needs for zoom level
    buffer_size = 1000  # meters
    geom = temp_gdf.geometry.iloc[0]
    minx, miny, maxx, maxy = geom.buffer(buffer_size).bounds
    ax.set_xlim(minx, maxx)
    ax.set_ylim(miny, maxy)
    
    # Add basemap
    ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
    
    ax.set_axis_off()
    
    # Save the plot
    filename = f'../static/images/map_snapshot_{index}.png'
    plt.savefig(filename, dpi=72, bbox_inches='tight')
    plt.close()  # Close the plot to free memory

# %%
import contextily as ctx

# List all available providers
for provider in ctx.providers.keys():
    print(provider)
# Out:
# OpenStreetMap
# MapTilesAPI
# OpenSeaMap
# OPNVKarte
# OpenTopoMap
# OpenRailwayMap
# OpenFireMap
# SafeCast
# Stadia
# Thunderforest
# BaseMapDE
# CyclOSM
# Jawg
# MapBox
# MapTiler
# TomTom
# Esri
# OpenWeatherMap
# HERE
# HEREv3
# FreeMapSK
# MtbMap
# CartoDB
# HikeBike
# BasemapAT
# nlmaps
# NASAGIBS
# NLS
# JusticeMap
# GeoportailFrance
# OneMapSG
# USGS
# WaymarkedTrails
# OpenAIP
# OpenSnowMap
# AzureMaps
# SwissFederalGeoportal
# TopPlusOpen
# Gaode
# Strava
# OrdnanceSurvey

# %%
import geopandas as gpd

# Load GeoJSON file
gdf = gpd.read_file('..static/data/centroids_data.geojson')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax)
plt.show()

# %%
gdf
# Out:
#      OBJECTID         GEOID        county   Tract  Low Lowmod  Lowmod_pct  \
# 0      199060  490111251021  Davis County  125102  120    340      0.1833
# 1      199061  490111251022  Davis County  125102  245    490      0.1892
# 2      199062  490111251031  Davis County  125103  370    850      0.3131
# 3      199063  490111251032  Davis County  125103  430   1000      0.4264
# 4      199064  490111251041  Davis County  125104  165    475      0.1967
# ..        ...           ...           ...     ...  ...    ...         ...
# 907    200607  490572112012  Weber County  211201   70    170      0.1560
# 908    200608  490572112013  Weber County  211201  365    975      0.4194
# 909    200609  490572112021  Weber County  211202  115    270      0.3354
# 910    200610  490572112022  Weber County  211202  620   1710      0.3963
# 911    200611  490572112023  Weber County  211202  135    360      0.2637
#
#     category                     geometry
# ...
