# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import numpy as np

# %%
# Load sensor data
sensor_data = pd.read_csv('../static/data/slc_daily_pm2.5_pm10_2016to2024.csv')

# Assuming your sensor data has columns 'latitude' and 'longitude'

# Convert sensor data DataFrame to GeoDataFrame
sensor_data['geometry'] = sensor_data.apply(lambda row: Point(row.longitude, row.latitude), axis=1)
sensor_gdf = gpd.GeoDataFrame(sensor_data, geometry='geometry')

# Load GeoJSON file
geojson_gdf = gpd.read_file('../static/data/converted_geojson_data.geojson')

# %%
# Ensure both GeoDataFrames use the same CRS
sensor_gdf = sensor_gdf.set_crs(geojson_gdf.crs)

# Perform spatial join
joined_gdf = gpd.sjoin(sensor_gdf, geojson_gdf, how="left", op='within')
# Out:
# /Users/juliakauffmann/miniforge3/envs/capstonev/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3517: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
# Function to categorize based on 'Lowmod_pct'
def categorize(lowmod_pct):
    if lowmod_pct > 0.75:
        return 'red'
    elif lowmod_pct > 0.5:
        return 'orange'
    elif lowmod_pct > 0.25:
        return 'yellow'
    else:
        return 'green'

# Apply categorization
joined_gdf['category'] = joined_gdf['Lowmod_pct'].apply(categorize)

# Log the categories (or export to CSV)
print(joined_gdf[['sensor_id', 'category']])
# Out:
#         sensor_id category
# 0              77      red
# 1              77      red
# 2              77      red
# 3              77      red
# 4              77      red
# ...           ...      ...
# 282304     208783    green
# 282305     208783    green
# 282306     208783    green
# 282307     208781   yellow
# 282308     208781   yellow
#
# [282309 rows x 2 columns]

# %%
df = joined_gdf.groupby('sensor_id').first().reset_index()[['sensor_id', 'category']]

# export to CSV
df.to_csv('sensor_categories.csv', index=False)

# %%
# get counts
counts = df.groupby('category').count().reset_index()
counts
# Out:
#   category  sensor_id
# 0    green         71
# 1   orange         54
# 2      red         16
# 3   yellow         81

# %%
# original data
bar_colors = ['green', 'yellow', 'orange', 'red']
yvalues = [71, 81, 54, 16]
labels = ["0-25%", "25-50%", "51-75%", "above 75%"]

fig, ax = plt.subplots()
# Plot bars with labels
bars = ax.bar(labels, yvalues, color=bar_colors)

ax.set_ylabel('Number of Sensors')
ax.set_xlabel('Income Category')
fig.suptitle('Sensor Count per Income Category (Percentage of low income families)')


legend_elements = [Patch(facecolor=bar_colors[i], label=labels[i]) for i in range(len(labels))]
# Create a legend with these custom elements
ax.legend(handles=legend_elements, title="Income Categories", loc="upper right")

plt.show()

# %%
joined_gdf
# Out:
#         Unnamed: 0  sensor_id   latitude   longitude  unix_timestamp  \
# 0                0         77  40.750816 -111.825290      1459468800
# 1                1         77  40.750816 -111.825290      1473379200
# 2                2         77  40.750816 -111.825290      1470700800
# 3                3         77  40.750816 -111.825290      1476662400
# 4                4         77  40.750816 -111.825290      1472774400
# ...            ...        ...        ...         ...             ...
# 282304      282304     208783  41.207040 -111.918755      1707004800
# 282305      282305     208783  41.207040 -111.918755      1706486400
# 282306      282306     208783  41.207040 -111.918755      1706918400
# 282307      282307     208781  41.210533 -111.932014      1706832000
# 282308      282308     208781  41.210533 -111.932014      1706918400
#
#             date  pm2.5_atm  pm10.0_atm  date_created       model  ...  Lmmi  \
# ...

# %%
areas_df = joined_gdf.groupby('Shape__Area').first().reset_index()[['Shape__Area','category']]
areas_df.groupby('category').count()
# Out:
#           Shape__Area
# category
# green              56
# orange             48
# red                12
# yellow             69

# %%
fig, ax = plt.subplots()

bar_colors = ['green', 'yellow', 'orange', 'red']
yvalues = [56, 69, 48, 12]
labels = ["0-25%", "25-50%", "51-75%", "above 75%"]

# Plot bars with labels
bars = ax.bar(labels, yvalues, color=bar_colors)

ax.set_ylabel('Number of Census Blocks')
ax.set_xlabel('Income Category')
fig.suptitle('Census Blocks per Income Category (Percentage of low income families)')


legend_elements = [Patch(facecolor=bar_colors[i], label=labels[i]) for i in range(len(labels))]
# Create a legend with these custom elements
ax.legend(handles=legend_elements, title="Income Categories", loc="upper right")

plt.show()

# %%
joined_gdf
# Out:
#         Unnamed: 0  sensor_id   latitude   longitude  unix_timestamp  \
# 0                0         77  40.750816 -111.825290      1459468800
# 1                1         77  40.750816 -111.825290      1473379200
# 2                2         77  40.750816 -111.825290      1470700800
# 3                3         77  40.750816 -111.825290      1476662400
# 4                4         77  40.750816 -111.825290      1472774400
# ...            ...        ...        ...         ...             ...
# 282304      282304     208783  41.207040 -111.918755      1707004800
# 282305      282305     208783  41.207040 -111.918755      1706486400
# 282306      282306     208783  41.207040 -111.918755      1706918400
# 282307      282307     208781  41.210533 -111.932014      1706832000
# 282308      282308     208781  41.210533 -111.932014      1706918400
#
#             date  pm2.5_atm  pm10.0_atm  date_created       model  ...  Lmmi  \
# ...
